# %% [markdown]
# # Financial Health Dashboard

# %%
import pandas as pd
import zipfile

# %%
# Step 1: Load the CSV file from the zip archive
zip_file_path = 'Financial Performance of Companies.zip'

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall()  # Extract all files into the current directory

# Load the CSV file into a pandas DataFrame
csv_file_path = 'snp500_companies_description.csv'
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame to confirm it's loaded correctly
print(df.head())
print(df.describe())
print(df.info())
# Out:
#   Company Major index membership Market capitalization Income (ttm)  \
# 0       A                S&P 500                41.05B        1.32B
# 1     AAL                S&P 500                10.65B      127.00M
# 2     AAP                S&P 500                 7.88B      501.90M
# 3    AAPL     DJIA, NDX, S&P 500              2336.71B       95.17B
# 4    ABBV                S&P 500               261.85B       11.78B
#
#   Revenue (ttm) Book value per share (mrq) Cash per share (mrq)  \
# 0         6.93B                      18.95                    -
# 1        48.97B                      -8.91                13.97
# 2        11.15B                      45.06                 4.52
# 3       387.54B                       3.57                 3.36
# 4        58.05B                       9.74                 5.27
#
#   Dividend (annual) Dividend yield (annual) Full time employees  ...  \
# 0              0.90                   0.64%               18300  ...
# 1                 -                       -              129700  ...
# 2              6.00                   4.54%               40000  ...
# 3              0.92                   0.60%              164000  ...
# 4              5.92                   3.96%               50000  ...
#
#   Performance (Quarter) Performance (Half Year) Performance (Year)  \
# 0                -6.59%                   7.56%              9.32%
# 1                14.14%                  17.76%             21.07%
# 2                -9.20%                 -25.89%            -34.12%
# 3                 7.70%                  -1.31%             -2.24%
# 4                -8.84%                   7.60%              1.43%
#
#   Performance (Year To Date)  Beta Average True Range (14)  \
# 0                     -5.53%  1.04                    3.27
# 1                     28.59%  1.56                    0.48
# 2                    -10.13%  1.15                    3.70
# 3                     18.46%  1.29                    3.30
# 4                     -7.65%  0.55                    2.80
#
#    Volatility (Week, Month) Previous close Current stock price  \
# 0               2.37% 2.09%         140.90              141.37
# 1               2.65% 2.73%          16.59               16.36
# 2               2.08% 2.39%         132.21              132.14
# 3               1.87% 1.86%         152.87              153.91
# 4               1.91% 1.86%         149.60              149.25
#
#   Performance (today)
# 0               0.33%
# 1              -1.41%
# 2              -0.05%
# 3               0.68%
# 4              -0.23%
#
# [5 rows x 73 columns]
#        Price-to-Sales (ttm)  Relative Strength Index  Relative volume  \
# count            496.000000               496.000000       496.000000
# mean               3.645141                44.376028         0.738810
# std                3.335920                10.516032         1.176879
# min                0.100000                14.650000         0.230000
# 25%                1.310000                37.605000         0.460000
# 50%                2.645000                43.915000         0.580000
# 75%                4.655000                51.515000         0.760000
# max               21.610000                78.240000        24.130000
#
#        Average True Range (14)  Previous close  Current stock price
# count               496.000000      496.000000           496.000000
# mean                  4.037661      171.426774           170.964637
# std                   6.911350      317.879747           318.199345
# min                   0.200000        3.020000             3.020000
# 25%                   1.305000       58.837500            58.747500
# 50%                   2.390000      106.845000           105.140000
# 75%                   4.375000      199.462500           199.042500
# max                 112.590000     5336.760000          5351.460000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 73 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Company                                                                    496 non-null    object
#  1   Major index membership                                                     496 non-null    object
#  2   Market capitalization                                                      496 non-null    object
#  3   Income (ttm)                                                               496 non-null    object
#  4   Revenue (ttm)                                                              496 non-null    object
#  5   Book value per share (mrq)                                                 496 non-null    object
#  6   Cash per share (mrq)                                                       496 non-null    object
#  7   Dividend (annual)                                                          496 non-null    object
#  8   Dividend yield (annual)                                                    496 non-null    object
#  9   Full time employees                                                        496 non-null    object
#  10  Stock has options trading on a market exchange                             496 non-null    object
#  11  Stock available to sell short                                              496 non-null    object
#  12  Analysts' mean recommendation (1=Buy 5=Sell)                               496 non-null    object
#  13  Price-to-Earnings (ttm)                                                    496 non-null    object
#  14  Forward Price-to-Earnings (next fiscal year)                               496 non-null    object
#  15  Price-to-Earnings-to-Growth                                                496 non-null    object
#  16  Price-to-Sales (ttm)                                                       496 non-null    float64
#  17  Price-to-Book (mrq)                                                        496 non-null    object
#  18  Price to cash per share (mrq)                                              496 non-null    object
#  19  Price to Free Cash Flow (ttm)                                              496 non-null    object
#  20  Quick Ratio (mrq)                                                          496 non-null    object
#  21  Current Ratio (mrq)                                                        496 non-null    object
#  22  Total Debt to Equity (mrq)                                                 496 non-null    object
#  23  Long Term Debt to Equity (mrq)                                             496 non-null    object
#  24  Distance from 20-Day Simple Moving Average                                 496 non-null    object
#  25  Diluted EPS (ttm)                                                          496 non-null    object
#  26  EPS estimate for next year                                                 496 non-null    object
#  27  EPS estimate for next quarter                                              496 non-null    object
#  28  EPS growth this year                                                       496 non-null    object
#  29  EPS growth next year                                                       496 non-null    object
#  30  Long term annual growth estimate (5 years)                                 496 non-null    object
#  31  Annual EPS growth past 5 years                                             496 non-null    object
#  32  Annual sales growth past 5 years                                           496 non-null    object
#  33  Quarterly revenue growth (YoY)                                             496 non-null    object
#  34  Quarterly earnings growth (YoY)                                            496 non-null    object
#  35  Earnings date<br><br>BMO = Before Market Open<br>AMC = After Market Close  496 non-null    object
#  36  Distance from 50-Day Simple Moving Average                                 496 non-null    object
#  37  Insider ownership                                                          496 non-null    object
#  38  Insider transactions (6-Month change in Insider Ownership)                 496 non-null    object
#  39  Institutional ownership                                                    496 non-null    object
#  40  Institutional transactions (3-Month change in Institutional Ownership)     496 non-null    object
#  41  Return on Assets (ttm)                                                     496 non-null    object
#  42  Return on Equity (ttm)                                                     496 non-null    object
#  43  Return on Investment (ttm)                                                 496 non-null    object
#  44  Gross Margin (ttm)                                                         496 non-null    object
#  45  Operating Margin (ttm)                                                     496 non-null    object
#  46  Net Profit Margin (ttm)                                                    496 non-null    object
#  47  Dividend Payout Ratio (ttm)                                                496 non-null    object
#  48  Distance from 200-Day Simple Moving Average                                496 non-null    object
#  49  Shares outstanding                                                         496 non-null    object
#  50  Shares float                                                               496 non-null    object
#  51  Short interest share / ratio                                               496 non-null    object
#  52  Short interest                                                             496 non-null    object
#  53  Analysts' mean target price                                                496 non-null    object
#  54  52-Week trading range                                                      496 non-null    object
#  55  Distance from 52-Week High                                                 496 non-null    object
#  56  Distance from 52-Week Low                                                  496 non-null    object
#  57  Relative Strength Index                                                    496 non-null    float64
#  58  Relative volume                                                            496 non-null    float64
#  59  Average volume (3 month)                                                   496 non-null    object
#  60  Volume                                                                     496 non-null    object
#  61  Performance (Week)                                                         496 non-null    object
#  62  Performance (Month)                                                        496 non-null    object
#  63  Performance (Quarter)                                                      496 non-null    object
#  64  Performance (Half Year)                                                    496 non-null    object
#  65  Performance (Year)                                                         496 non-null    object
#  66  Performance (Year To Date)                                                 496 non-null    object
#  67  Beta                                                                       496 non-null    object
#  68  Average True Range (14)                                                    496 non-null    float64
#  69  Volatility (Week, Month)                                                   496 non-null    object
#  70  Previous close                                                             496 non-null    float64
#  71  Current stock price                                                        496 non-null    float64
#  72  Performance (today)                                                        496 non-null    object
# dtypes: float64(6), object(67)
# memory usage: 283.0+ KB
# None

# %%
# Data Preparation and Cleaning

# %%
# Step 1: Convert financial columns (e.g., Market capitalization, Income, Revenue) from strings to numeric
def convert_financial_values(value):
    """Converts string financial values like '41.05B' or '10.65M' into float."""
    if pd.isna(value) or value == '-' or value == '':
        return 0  # Replace missing or invalid values with 0
    # If the value is already a float or int, return it as is
    if isinstance(value, (int, float)):
        return value
    # Handle string values with 'B' or 'M'
    if 'B' in value:
        return float(value.replace('B', '').replace(',', '')) * 1e9
    if 'M' in value:
        return float(value.replace('M', '').replace(',', '')) * 1e6
    # Default: remove commas and convert to float
    return float(value.replace(',', ''))

# Apply conversion to relevant financial columns
financial_columns = ['Market capitalization', 'Income (ttm)', 'Revenue (ttm)', 'Book value per share (mrq)', 'Cash per share (mrq)']
for col in financial_columns:
    df[col] = df[col].apply(convert_financial_values)

# %%
# Step 2: Convert percentage columns by handling multiple values and removing '%' symbol
def convert_percentage(value):
    """Converts string percentage values like '9.32%' into float. Handles multiple values like '2.37% 2.09%' by averaging."""
    if pd.isna(value) or value == '-' or value == '':
        return 0  # Replace missing or invalid values with 0
    # If the value is already a float or int, return it as is
    if isinstance(value, (int, float)):
        return value
    # Remove the '%' symbol before processing
    value = value.replace('%', '')
    # Handle cases where there are two percentage values (e.g., '2.37 2.09')
    if ' ' in value:
        values = [float(v) for v in value.split()]
        return sum(values) / len(values)  # Return the average of the two values
    # Handle single percentage values
    return float(value)

# Apply conversion to relevant percentage columns
percentage_columns = ['Dividend yield (annual)', 'Performance (Quarter)', 'Performance (Half Year)', 'Performance (Year)', 'Performance (Year To Date)', 'Volatility (Week, Month)', 'Performance (today)']
for col in percentage_columns:
    df[col] = df[col].apply(convert_percentage)

# %%
# Step 3: Convert ratio columns from strings to numeric (e.g., Current Ratio, Quick Ratio)
ratio_columns = ['Current Ratio (mrq)', 'Quick Ratio (mrq)', 'Total Debt to Equity (mrq)', 'Long Term Debt to Equity (mrq)']
for col in ratio_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric, set errors to NaN

# Step 4: Handle missing or invalid values (e.g., '-' or missing values)
df.fillna(0, inplace=True)  # Replace NaN with 0 for simplicity

# Step 5: Convert any other relevant columns (e.g., 'Price-to-Earnings (ttm)') from strings to float where necessary
df['Price-to-Earnings (ttm)'] = pd.to_numeric(df['Price-to-Earnings (ttm)'], errors='coerce')

# Display cleaned data info and a sample to verify the changes
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 73 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Company                                                                    496 non-null    object
#  1   Major index membership                                                     496 non-null    object
#  2   Market capitalization                                                      496 non-null    float64
#  3   Income (ttm)                                                               496 non-null    float64
#  4   Revenue (ttm)                                                              496 non-null    float64
#  5   Book value per share (mrq)                                                 496 non-null    float64
#  6   Cash per share (mrq)                                                       496 non-null    float64
#  7   Dividend (annual)                                                          496 non-null    object
#  8   Dividend yield (annual)                                                    496 non-null    float64
#  9   Full time employees                                                        496 non-null    object
#  10  Stock has options trading on a market exchange                             496 non-null    object
#  11  Stock available to sell short                                              496 non-null    object
#  12  Analysts' mean recommendation (1=Buy 5=Sell)                               496 non-null    object
#  13  Price-to-Earnings (ttm)                                                    457 non-null    float64
#  14  Forward Price-to-Earnings (next fiscal year)                               496 non-null    object
#  15  Price-to-Earnings-to-Growth                                                496 non-null    object
#  16  Price-to-Sales (ttm)                                                       496 non-null    float64
#  17  Price-to-Book (mrq)                                                        496 non-null    object
#  18  Price to cash per share (mrq)                                              496 non-null    object
#  19  Price to Free Cash Flow (ttm)                                              496 non-null    object
#  20  Quick Ratio (mrq)                                                          496 non-null    float64
#  21  Current Ratio (mrq)                                                        496 non-null    float64
#  22  Total Debt to Equity (mrq)                                                 496 non-null    float64
#  23  Long Term Debt to Equity (mrq)                                             496 non-null    float64
#  24  Distance from 20-Day Simple Moving Average                                 496 non-null    object
#  25  Diluted EPS (ttm)                                                          496 non-null    object
#  26  EPS estimate for next year                                                 496 non-null    object
#  27  EPS estimate for next quarter                                              496 non-null    object
#  28  EPS growth this year                                                       496 non-null    object
#  29  EPS growth next year                                                       496 non-null    object
#  30  Long term annual growth estimate (5 years)                                 496 non-null    object
#  31  Annual EPS growth past 5 years                                             496 non-null    object
#  32  Annual sales growth past 5 years                                           496 non-null    object
#  33  Quarterly revenue growth (YoY)                                             496 non-null    object
#  34  Quarterly earnings growth (YoY)                                            496 non-null    object
#  35  Earnings date<br><br>BMO = Before Market Open<br>AMC = After Market Close  496 non-null    object
#  36  Distance from 50-Day Simple Moving Average                                 496 non-null    object
#  37  Insider ownership                                                          496 non-null    object
#  38  Insider transactions (6-Month change in Insider Ownership)                 496 non-null    object
#  39  Institutional ownership                                                    496 non-null    object
#  40  Institutional transactions (3-Month change in Institutional Ownership)     496 non-null    object
#  41  Return on Assets (ttm)                                                     496 non-null    object
#  42  Return on Equity (ttm)                                                     496 non-null    object
#  43  Return on Investment (ttm)                                                 496 non-null    object
#  44  Gross Margin (ttm)                                                         496 non-null    object
#  45  Operating Margin (ttm)                                                     496 non-null    object
#  46  Net Profit Margin (ttm)                                                    496 non-null    object
#  47  Dividend Payout Ratio (ttm)                                                496 non-null    object
#  48  Distance from 200-Day Simple Moving Average                                496 non-null    object
#  49  Shares outstanding                                                         496 non-null    object
#  50  Shares float                                                               496 non-null    object
#  51  Short interest share / ratio                                               496 non-null    object
#  52  Short interest                                                             496 non-null    object
#  53  Analysts' mean target price                                                496 non-null    object
#  54  52-Week trading range                                                      496 non-null    object
#  55  Distance from 52-Week High                                                 496 non-null    object
#  56  Distance from 52-Week Low                                                  496 non-null    object
#  57  Relative Strength Index                                                    496 non-null    float64
#  58  Relative volume                                                            496 non-null    float64
#  59  Average volume (3 month)                                                   496 non-null    object
#  60  Volume                                                                     496 non-null    object
#  61  Performance (Week)                                                         496 non-null    object
#  62  Performance (Month)                                                        496 non-null    object
#  63  Performance (Quarter)                                                      496 non-null    float64
#  64  Performance (Half Year)                                                    496 non-null    float64
#  65  Performance (Year)                                                         496 non-null    float64
#  66  Performance (Year To Date)                                                 496 non-null    float64
#  67  Beta                                                                       496 non-null    object
#  68  Average True Range (14)                                                    496 non-null    float64
#  69  Volatility (Week, Month)                                                   496 non-null    float64
#  70  Previous close                                                             496 non-null    float64
#  71  Current stock price                                                        496 non-null    float64
#  72  Performance (today)                                                        496 non-null    float64
# dtypes: float64(23), object(50)
# memory usage: 283.0+ KB
# None
#   Company Major index membership  Market capitalization  Income (ttm)  \
# 0       A                S&P 500           4.105000e+10  1.320000e+09
# 1     AAL                S&P 500           1.065000e+10  1.270000e+08
# 2     AAP                S&P 500           7.880000e+09  5.019000e+08
# 3    AAPL     DJIA, NDX, S&P 500           2.336710e+12  9.517000e+10
# 4    ABBV                S&P 500           2.618500e+11  1.178000e+10
#
#    Revenue (ttm)  Book value per share (mrq)  Cash per share (mrq)  \
# 0   6.930000e+09                       18.95                  0.00
# 1   4.897000e+10                       -8.91                 13.97
# 2   1.115000e+10                       45.06                  4.52
# 3   3.875400e+11                        3.57                  3.36
# 4   5.805000e+10                        9.74                  5.27
#
#   Dividend (annual)  Dividend yield (annual) Full time employees  ...  \
# 0              0.90                     0.64               18300  ...
# 1                 -                     0.00              129700  ...
# 2              6.00                     4.54               40000  ...
# 3              0.92                     0.60              164000  ...
# 4              5.92                     3.96               50000  ...
#
#   Performance (Quarter) Performance (Half Year) Performance (Year)  \
# 0                 -6.59                    7.56               9.32
# 1                 14.14                   17.76              21.07
# 2                 -9.20                  -25.89             -34.12
# 3                  7.70                   -1.31              -2.24
# 4                 -8.84                    7.60               1.43
#
#    Performance (Year To Date)  Beta Average True Range (14)  \
# 0                       -5.53  1.04                    3.27
# 1                       28.59  1.56                    0.48
# 2                      -10.13  1.15                    3.70
# 3                       18.46  1.29                    3.30
# 4                       -7.65  0.55                    2.80
#
#    Volatility (Week, Month) Previous close Current stock price  \
# 0                     2.230         140.90              141.37
# 1                     2.690          16.59               16.36
# 2                     2.235         132.21              132.14
# 3                     1.865         152.87              153.91
# 4                     1.885         149.60              149.25
#
#   Performance (today)
# 0                0.33
# 1               -1.41
# 2               -0.05
# 3                0.68
# 4               -0.23
#
# [5 rows x 73 columns]

# %%
# Preparing Data for Tableau Visualizations

# %%
# Step 1: Assume or create mock 'Expenses', 'Current Assets', and 'Current Liabilities' columns
# For demonstration, we'll assume Expenses are 80% of Revenue
df['Expenses'] = df['Revenue (ttm)'] * 0.8  # Example: Assuming 80% of revenue is expenses

# For Current Assets and Liabilities, create mock values (replace with real values if available)
df['Current Assets'] = df['Revenue (ttm)'] * 0.6  # Assuming 60% of revenue is current assets
df['Current Liabilities'] = df['Revenue (ttm)'] * 0.4  # Assuming 40% of revenue is current liabilities
df['Inventory'] = df['Revenue (ttm)'] * 0.2  # Assuming 20% of revenue is inventory

# Step 2: Calculate Profit (Profit = Revenue - Expenses)
df['Profit'] = df['Revenue (ttm)'] - df['Expenses']

# Step 3: Calculate Financial Ratios
df['Current Ratio'] = df['Current Assets'] / df['Current Liabilities']
df['Quick Ratio'] = (df['Current Assets'] - df['Inventory']) / df['Current Liabilities']

# Step 4: Prepare Data for Tableau

# 1. Profit and Loss Statement (For Line Chart in Tableau)
# Grouping by 'Company' to see overall financial performance (you can add Date if time-based data exists)
profit_loss_over_time = df[['Company', 'Revenue (ttm)', 'Expenses', 'Profit']]

# 2. Revenue vs. Expenses (For Bar Chart in Tableau)
# Grouping by 'Company' to compare revenue and expenses
revenue_vs_expenses = df[['Company', 'Revenue (ttm)', 'Expenses']]

# 3. Financial Ratios (For Gauge Chart in Tableau)
# Keep necessary financial ratios for visualization
financial_ratios = df[['Company', 'Current Ratio', 'Quick Ratio']]

# %%
# Step 5: Save Prepared Data for Tableau

# Save profit and loss statement
profit_loss_csv = 'profit_loss_over_time.csv'
profit_loss_over_time.to_csv(profit_loss_csv, index=False)

# Save revenue vs expenses data
revenue_vs_expenses_csv = 'revenue_vs_expenses.csv'
revenue_vs_expenses.to_csv(revenue_vs_expenses_csv, index=False)

# Save financial ratios data
financial_ratios_csv = 'financial_ratios.csv'
financial_ratios.to_csv(financial_ratios_csv, index=False)

print(f"Data prepared for Tableau visualization:")
print(f"Profit and Loss: {profit_loss_csv}")
print(f"Revenue vs Expenses: {revenue_vs_expenses_csv}")
print(f"Financial Ratios: {financial_ratios_csv}")
# Out:
# Data prepared for Tableau visualization:
# Profit and Loss: profit_loss_over_time.csv
# Revenue vs Expenses: revenue_vs_expenses.csv
# Financial Ratios: financial_ratios.csv

# %%
# You can then use Tableau to build the visualizations:
# Profit and Loss Statement (Line Chart),
# Revenue vs. Expenses (Bar Chart),
# Financial Ratios (Gauge Chart).
